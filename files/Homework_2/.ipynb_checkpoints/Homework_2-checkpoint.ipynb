# %% [markdown]
# # Homework 2

# %% [markdown]
# - In this homework, since my school id's last digit is 8, I dealed with the data " Newly Established Total Firms" provided by https://evds2.tcmb.gov.tr/
# - My aim is to predict the values in month 2021-04 but I could not decide which predictor to use so at first I did some manipulations and  visualizations to understand the data.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("firms_total.xlsx")
firms = df.copy()
firms.drop("Unnamed: 2" , axis = 'columns' , inplace = True)
firms.set_index("Date", inplace = True)
firms.columns = ['Total']
firms.drop(firms.tail(8).index,
        inplace = True)
firms
# Out:
#          Total
# Date
# 2010-01   5000
# 2010-02   4230
# 2010-03   5055
# 2010-04   4466
# 2010-05   4072
# ...        ...
# 2020-11   8782
# 2020-12   8560
# 2021-01  11428
# 2021-02  10001
# 2021-03  11034
#
# [135 rows x 1 columns]

# %%
firms.describe().T # overall statistics
# Out:
#        count  unique   top  freq
# Total    135     134  5000     2

# %%
firms.isnull().values.any() # checked whether there is null values or not
# Out:
# False

# %%
sns.set(rc={'figure.figsize':(12,9)})
firms.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# - From the visualization, it is clear that there is an upward trend over the years so I am going to add a trend variable to my data set and model it. Then, I'm going to check residuals for normality assumptions and whether I can add more variable like seasonality or lags.

# %%
firms.insert(1, 'trend', range(1,len(firms)+1))
firms
# Out:
#          Total  trend
# Date
# 2010-01   5000      1
# 2010-02   4230      2
# 2010-03   5055      3
# 2010-04   4466      4
# 2010-05   4072      5
# ...        ...    ...
# 2020-11   8782    131
# 2020-12   8560    132
# 2021-01  11428    133
# 2021-02  10001    134
# 2021-03  11034    135
#
# [135 rows x 2 columns]

# %%
import statsmodels.api as sm
X = firms["trend"]
y = firms["Total"]
lm = sm.OLS(y.astype(float),X)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Total   R-squared (uncentered):                   0.888
# Model:                            OLS   Adj. R-squared (uncentered):              0.887
# Method:                 Least Squares   F-statistic:                              1060.
# Date:                Tue, 04 May 2021   Prob (F-statistic):                    1.68e-65
# Time:                        20:47:40   Log-Likelihood:                         -1218.8
# No. Observations:                 135   AIC:                                      2440.
# Df Residuals:                     134   BIC:                                      2442.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# trend         72.3478      2.222     32.554      0.000      67.952      76.743
# ==============================================================================
# Omnibus:                        8.790   Durbin-Watson:                   0.395
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):               13.465
# Skew:                          -0.301   Prob(JB):                      0.00119
# Kurtosis:                       4.426   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# - From the sumamry of the model, adjusted R-squared, p value of the F-statistic and the t value of trend seems significant. So trend component explains some of the model. Now I need to check residuals.

# %%
import matplotlib.pyplot as plt 
sns.set(rc={'figure.figsize':(11.7,8.27)})
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(model, 'trend', fig=fig)

# %%
plt.plot(model.resid);

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(model.resid)
plt.show();

# %% [markdown]
# - From the residual analysis, it can be seen that the normality assumptions are failed because the variance between the zero mean is high and also residuals seem to have a autocorrelation in itself. We can add a seasonality variable, month information, to see whether the model is better or not.

# %%
df.drop(df.tail(10).index,
        inplace = True)
df
# Out:
#         Date TP AC2 TOP A Unnamed: 2
# 0    2010-01         5000        NaN
# 1    2010-02         4230        NaN
# 2    2010-03         5055        NaN
# 3    2010-04         4466        NaN
# 4    2010-05         4072        NaN
# ..       ...          ...        ...
# 130  2020-11         8782        NaN
# 131  2020-12         8560        NaN
# 132  2021-01        11428        NaN
# 133  2021-02        10001        NaN
# 134  2021-03        11034        NaN
#
# [135 rows x 3 columns]

# %%
firms['month'] = pd.DatetimeIndex(df['Date']).month
firms
# Out:
#          Total  trend  month
# Date
# 2010-01   5000      1      1
# 2010-02   4230      2      2
# 2010-03   5055      3      3
# 2010-04   4466      4      4
# 2010-05   4072      5      5
# ...        ...    ...    ...
# 2020-11   8782    131     11
# 2020-12   8560    132     12
# 2021-01  11428    133      1
# 2021-02  10001    134      2
# 2021-03  11034    135      3
#
# [135 rows x 3 columns]

# %%
X = firms.drop("Total", axis = 1)
X
# Out:
#          trend  month
# Date
# 2010-01      1      1
# 2010-02      2      2
# 2010-03      3      3
# 2010-04      4      4
# 2010-05      5      5
# ...        ...    ...
# 2020-11    131     11
# 2020-12    132     12
# 2021-01    133      1
# 2021-02    134      2
# 2021-03    135      3
#
# [135 rows x 2 columns]

# %%
y = firms["Total"]
y
# Out:
# Date
# 2010-01     5000
# 2010-02     4230
# 2010-03     5055
# 2010-04     4466
# 2010-05     4072
#            ...
# 2020-11     8782
# 2020-12     8560
# 2021-01    11428
# 2021-02    10001
# 2021-03    11034
# Name: Total, Length: 135, dtype: object

# %%
lm = sm.OLS(y.astype(float),X)
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Total   R-squared (uncentered):                   0.902
# Model:                            OLS   Adj. R-squared (uncentered):              0.901
# Method:                 Least Squares   F-statistic:                              614.5
# Date:                Tue, 04 May 2021   Prob (F-statistic):                    6.53e-68
# Time:                        20:47:46   Log-Likelihood:                         -1209.4
# No. Observations:                 135   AIC:                                      2423.
# Df Residuals:                     133   BIC:                                      2429.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# trend         61.1132      3.268     18.701      0.000      54.649      67.577
# month        156.7471     35.160      4.458      0.000      87.202     226.292
# ==============================================================================
# Omnibus:                        2.343   Durbin-Watson:                   0.674
# Prob(Omnibus):                  0.310   Jarque-Bera (JB):                2.001
# Skew:                          -0.126   Prob(JB):                        0.368
# Kurtosis:                       3.540   Cond. No.                         17.0
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(model, 'month', fig=fig)

# %%
plt.plot(model.resid);

# %%
new_df = pd.DataFrame(model.fittedvalues,  index = model.fittedvalues.index)
new_df.columns = ["Fitted"]
new_df["Real"] = firms["Total"]
plt.plot(new_df.Fitted, c = "r")
plt.plot(new_df.Real, c = "b")
plt.show()

# %%
plot_acf(model.resid)
plt.show();

# %% [markdown]
# - In the second attempt, residuals seem to behave more like normal distribution but the errors are stil high and the ACF seems to fail since the lag 0 has a very high autocorrelation. Thus, I decided to use the lag as regressor in the model.

# %%
lag = firms["Total"].shift(-1)
firms["lag"] = lag
firms.drop(firms.tail(1).index, inplace = True)

# %%
X = firms.drop("Total", axis = 1)
X
# Out:
#          trend  month    lag
# Date
# 2010-01      1      1   4230
# 2010-02      2      2   5055
# 2010-03      3      3   4466
# 2010-04      4      4   4072
# 2010-05      5      5   4327
# ...        ...    ...    ...
# 2020-10    130     10   8782
# 2020-11    131     11   8560
# 2020-12    132     12  11428
# 2021-01    133      1  10001
# 2021-02    134      2  11034
#
# [134 rows x 3 columns]

# %%
y = firms["Total"]
y
# Out:
# Date
# 2010-01     5000
# 2010-02     4230
# 2010-03     5055
# 2010-04     4466
# 2010-05     4072
#            ...
# 2020-10    10419
# 2020-11     8782
# 2020-12     8560
# 2021-01    11428
# 2021-02    10001
# Name: Total, Length: 134, dtype: object

# %%
lm = sm.OLS(y.astype(float),X.astype(float))
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Total   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.958
# Method:                 Least Squares   F-statistic:                              1027.
# Date:                Tue, 04 May 2021   Prob (F-statistic):                    8.67e-91
# Time:                        20:47:55   Log-Likelihood:                         -1140.7
# No. Observations:                 134   AIC:                                      2287.
# Df Residuals:                     131   BIC:                                      2296.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# trend         12.7579      4.084      3.124      0.002       4.678      20.838
# month        -29.8508     26.770     -1.115      0.267     -82.808      23.106
# lag            0.8429      0.062     13.674      0.000       0.721       0.965
# ==============================================================================
# Omnibus:                       47.462   Durbin-Watson:                   2.370
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              237.004
# Skew:                          -1.110   Prob(JB):                     3.43e-52
# Kurtosis:                       9.125   Cond. No.                     1.53e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.53e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# - It is necessary to note that now the prdictor month became insignificant after we added the lag as regressor but the overall model score has increased.

# %%
plt.plot(model.resid);

# %% [markdown]
# - Residuals got closer to the zero mean and no signs of autocorrelation.

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(model, 'lag', fig=fig)

# %%
plot_acf(model.resid)
plt.show();

# %% [markdown]
# - We still have a high autocorrelation in lag 0

# %%
new_df = pd.DataFrame(model.fittedvalues,  index = model.fittedvalues.index)
new_df.columns = ["Fitted"]
new_df["Real"] = firms["Total"]
plt.plot(new_df.Fitted, c = "r")
plt.plot(new_df.Real, c = "b")
plt.show()

# %% [markdown]
# - Now our errors got smaller and we have a better model to predict but since the month variable seemed unsignificant, I want to model it without month predictor.

# %%
X = firms.drop( "Total", axis = 1)
X = X.drop("month", axis = 1)
X
# Out:
#          trend    lag
# Date
# 2010-01      1   4230
# 2010-02      2   5055
# 2010-03      3   4466
# 2010-04      4   4072
# 2010-05      5   4327
# ...        ...    ...
# 2020-10    130   8782
# 2020-11    131   8560
# 2020-12    132  11428
# 2021-01    133  10001
# 2021-02    134  11034
#
# [134 rows x 2 columns]

# %%
y = firms["Total"]
y
# Out:
# Date
# 2010-01     5000
# 2010-02     4230
# 2010-03     5055
# 2010-04     4466
# 2010-05     4072
#            ...
# 2020-10    10419
# 2020-11     8782
# 2020-12     8560
# 2021-01    11428
# 2021-02    10001
# Name: Total, Length: 134, dtype: object

# %%
lm = sm.OLS(y.astype(float),X.astype(float))
model = lm.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Total   R-squared (uncentered):                   0.959
# Model:                            OLS   Adj. R-squared (uncentered):              0.958
# Method:                 Least Squares   F-statistic:                              1537.
# Date:                Tue, 04 May 2021   Prob (F-statistic):                    3.63e-92
# Time:                        20:50:39   Log-Likelihood:                         -1141.3
# No. Observations:                 134   AIC:                                      2287.
# Df Residuals:                     132   BIC:                                      2292.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# trend         13.2198      4.067      3.250      0.001       5.175      21.265
# lag            0.8068      0.053     15.363      0.000       0.703       0.911
# ==============================================================================
# Omnibus:                       41.753   Durbin-Watson:                   2.359
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              183.203
# Skew:                          -0.993   Prob(JB):                     1.65e-40
# Kurtosis:                       8.373   Cond. No.                         233.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
new_df = pd.DataFrame(model.fittedvalues,  index = model.fittedvalues.index)
new_df.columns = ["Fitted"]
new_df["Real"] = firms["Total"]
plt.plot(new_df.Fitted, c = "r")
plt.plot(new_df.Real, c = "b")
plt.show()

# %%
plot_acf(model.resid)
plt.show();

# %%
model.predict()
# Out:
# array([ 3425.91523501,  4104.73166628,  3642.75581899,  3338.10281069,
#         3557.05248186,  3289.51152788,  3617.37701065,  3210.26246106,
#         3575.23999816,  2875.26293293,  4129.31620621,  5071.9509367 ,
#         4205.7764108 ,  4441.66854155,  4052.30323533,  3786.37584893,
#         4143.28554813,  3484.45445617,  3337.12428685,  3232.55365837,
#         3837.95276478,  3197.67769998,  3907.95869905,  4615.81934675,
#         3472.11119721,  3298.96394662,  2996.73128968,  2992.20185112,
#         2870.68876306,  2478.90310547,  2340.44755783,  2585.21431028,
#         2909.0458741 ,  3205.44678908,  2995.18748416,  3895.0626738 ,
#         3966.37091146,  4163.53742032,  4207.41500914,  4139.1496512 ,
#         3769.14715593,  3834.00112328,  3054.95924666,  3858.02038154,
#         3445.25834542,  4412.09658959,  4131.64709497,  5407.48353058,
#         4496.93589625,  4715.88556742,  4675.05085833,  4534.17495932,
#         4614.35781868,  4258.87743162,  4008.27893722,  4940.42547844,
#         4301.76398122,  4779.69124887,  5125.30597502,  6013.88619159,
#         5250.97999077,  5734.55474495,  5691.29968448,  5392.2941627 ,
#         5616.08453661,  4712.79795639,  4941.42903304,  5154.73121769,
#         5108.24902207,  5378.02607199,  5952.76739439,  6513.79339237,
#         6099.41778868,  6720.14578709,  5719.23836832,  5379.08687327,
#         5512.51746274,  3561.21873977,  4701.51549872,  4078.98967729,
#         5396.77886996,  5595.55894639,  5038.38261192,  6173.03188434,
#         5655.38795557,  6095.39638511,  6350.65132681,  6205.74150886,
#         6048.72993405,  5440.72622084,  6587.47725011,  5334.85328897,
#         6870.47410484,  6866.75145007,  6094.97062756,  9039.23594015,
#         7064.54048728,  7410.96199722,  8217.25026725,  8015.86558402,
#         5852.38272437,  6891.83150961,  5827.99495525,  6533.43525158,
#         7164.65143926,  7137.53205459,  6611.01350413,  8178.0988878 ,
#         6904.49854813,  7223.48940922,  6944.65348218,  6965.1343411 ,
#         5238.12151165,  7397.38619692,  5868.84217972,  7830.44483653,
#         8375.33515872,  7879.47439227,  7988.70146805, 10131.02369373,
#         9092.19743685,  8409.96961499,  3947.95973864,  4446.05660103,
#         9493.60725323, 10051.40611605,  9340.13407777, 10376.35572785,
#        10111.23512523,  8803.7498664 ,  8637.86366991, 10964.93938343,
#         9826.87872042, 10673.50617993])

# %%
# Out:
# pandas.core.indexes.base.Index
